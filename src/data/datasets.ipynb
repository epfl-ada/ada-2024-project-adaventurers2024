# %%
import pandas as pd

# %%
def extract_year(date):
    if date:
        return str(date).split('-')[0]
    return None

# %% [markdown]
# #### CMU dataset
#
# Link to download the data: https://www.cs.cmu.edu/~ark/personas/

# %%
df_cmu_movie_metadata = pd.read_csv('../../data/cmu/movie.metadata.tsv', sep='\t', header=None)
df_cmu_movie_metadata.columns = ['wikipedia_movie_id', 'freebase_movie_id', 'name', 'release_date', 'revenue', 'runtime', 'languages', 'countries', 'genres']
df_cmu_movie_metadata.sample(5)
# Out:
#        wikipedia_movie_id freebase_movie_id                  name  \
# 8047              7643463         /m/0kvd1p         Double Dragon
# 18846            30731965        /m/0gfgnn5  An Angel Named Billy
# 80859             4405649         /m/0c0jgy    The Little Vampire
# 25493             2631788         /m/07t0lc             Arabesque
# 27196            32127870        /m/0gwz_3r                Baader
#
#       release_date     revenue  runtime                           languages  \
# 8047    1994-11-04   2341309.0     95.0  {"/m/02h40lc": "English Language"}
# 18846          NaN         NaN    120.0                                  {}
# 80859         2000  27965865.0     95.0                                  {}
# 25493   1966-05-05         NaN    106.0  {"/m/02h40lc": "English Language"}
# 27196   2002-02-15         NaN    110.0                                  {}
#
#                                                countries  \
# 8047           {"/m/09c7w0": "United States of America"}
# 18846                                                 {}
# 80859  {"/m/09c7w0": "United States of America", "/m/...
# 25493          {"/m/09c7w0": "United States of America"}
# 27196                            {"/m/0345h": "Germany"}
#
#                                                   genres
# 8047   {"/m/06n90": "Science Fiction", "/m/04t2t": "M...
# 18846                            {"/m/07s9rl0": "Drama"}
# 80859  {"/m/0hj3myq": "Children's/Family", "/m/0bj8m2...
# 25493  {"/m/01jfsb": "Thriller", "/m/0c3351": "Suspen...
# 27196  {"/m/0lsxr": "Crime Fiction", "/m/01jfsb": "Th...

# %%
df_cmu_movie_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81741 entries, 0 to 81740
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   wikipedia_movie_id  81741 non-null  int64
#  1   freebase_movie_id   81741 non-null  object
#  2   name                81741 non-null  object
#  3   release_date        74839 non-null  object
#  4   revenue             8401 non-null   float64
#  5   runtime             61291 non-null  float64
#  6   languages           81741 non-null  object
#  7   countries           81741 non-null  object
#  8   genres              81741 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 5.6+ MB

# %%
print("CMU Movie Metadata shape before filtering: ", df_cmu_movie_metadata.shape)
# Out:
# CMU Movie Metadata shape before filtering:  (81741, 9)

# %%
print("Number of movies with revenue information: ", df_cmu_movie_metadata[df_cmu_movie_metadata['revenue'].notnull()].shape)
# We need to update this column with updated information
# Out:
# Number of movies with revenue information:  (8401, 9)

# %%
print("Number of movies with release date information: ", df_cmu_movie_metadata[df_cmu_movie_metadata['release_date'].notnull()].shape)
df_cmu_movie_metadata.dropna(subset=['release_date'], inplace=True)
# Out:
# Number of movies with release date information:  (74839, 9)

# %%
df_cmu_movie_metadata['release_year'] = df_cmu_movie_metadata['release_date'].apply(extract_year)
df_cmu_movie_metadata.head()
# Out:
#    wikipedia_movie_id freebase_movie_id  \
# 0              975900         /m/03vyhn
# 1             3196793         /m/08yl5d
# 2            28463795        /m/0crgdbh
# 3             9363483        /m/0285_cd
# 4              261236         /m/01mrr1
#
#                                                 name release_date     revenue  \
# 0                                     Ghosts of Mars   2001-08-24  14010832.0
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16         NaN
# 2                                        Brun bitter         1988         NaN
# 3                                   White Of The Eye         1987         NaN
# 4                                  A Woman in Flames         1983         NaN
#
#    runtime                           languages  \
# 0     98.0  {"/m/02h40lc": "English Language"}
# 1     95.0  {"/m/02h40lc": "English Language"}
# 2     83.0  {"/m/05f_3": "Norwegian Language"}
# 3    110.0  {"/m/02h40lc": "English Language"}
# 4    106.0   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres release_year
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...         2001
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...         2000
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...         1988
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...         1987
# 4                            {"/m/07s9rl0": "Drama"}         1983

# %%
df_cmu_plot_summaries = pd.read_csv('../../data/cmu/plot_summaries.txt', sep='\t', header=None)
df_cmu_plot_summaries.columns = ['wiki_id', 'summary']
df_cmu_plot_summaries.sample(5)
# Out:
#         wiki_id                                            summary
# 10675  11614763  In a Trieste gambling casino, the cynical Coun...
# 38255   9179879  The big high school dance in Santa Barbara is ...
# 12409  34982215  One night, a young traveller seeks shelter in ...
# 21357   8476961  Anna, a modern day Parisian psychologist, is r...
# 4869   36252599  Sivankutty loses his job as a police officer w...

# %%
df_cmu_character_metadata = pd.read_csv('../../data/cmu/character.metadata.tsv', sep='\t', header=None)
df_cmu_character_metadata.columns = [
    "wikipedia_movie_id", "freebase_movie_id", "movie_release_date", "character_name",
    "actor_date_of_birth", "actor_gender", "actor_height_in_meters", "actor_ethnicity_freebase_id",
    "actor_name", "actor_age_at_movie_release", "freebase_character_actor_map_id",
    "freebase_character_id", "freebase_actor_id"
]

df_cmu_character_metadata.sample(5)
# Out:
#         wikipedia_movie_id freebase_movie_id movie_release_date  \
# 43688               346196         /m/01yr53         1984-05-14
# 115432            32367366        /m/0ch5kjd               1974
# 238821              231829         /m/01hqhm         1999-12-08
# 386454             2062208         /m/06jfpb         1989-08-11
# 190072            33026594        /m/0h526ws                NaN
#
#        character_name actor_date_of_birth actor_gender  \
# 43688             NaN          1946-09-19            M
# 115432            NaN                 NaN          NaN
# 238821      Gwenovier          1962-05-12            F
# 386454         Pandit          1920-06-14            M
# 190072            NaN          1876-05-08            M
#
#         actor_height_in_meters actor_ethnicity_freebase_id        actor_name  \
# 43688                      NaN                         NaN   Michael Elphick
# 115432                     NaN                         NaN       Sylvio Dieu
# 238821                     NaN                     /m/0x67       April Grace
# 386454                     NaN                         NaN    Bharat Bhushan
# 190072                     NaN                         NaN  Monroe Salisbury
#
#         actor_age_at_movie_release freebase_character_actor_map_id  \
# 43688                         37.0                       /m/0k4_3t
# 115432                         NaN                      /m/0gc74gm
# 238821                        37.0                       /m/0k0bcx
# 386454                        69.0                      /m/0h77s7d
# 190072                         NaN                      /m/0h588vk
#
#        freebase_character_id freebase_actor_id
# 43688                    NaN         /m/07rqcj
# 115432                   NaN        /m/0gc74gr
# 238821            /m/0cj5y2f         /m/0dm44t
# 386454            /m/0h77s7h         /m/02vmzb
# 190072                   NaN        /m/04ctj37

# %% [markdown]
# #### Tropes dataset
#
# Link to download the data: https://drive.google.com/file/d/1Duyz5ATlLHzwMidj15bWVnWHpdE4aRXn/view?usp=sharing

# %%
df_tropes = pd.read_csv('../../data/tropes/tropes.csv', index_col=0)
df_tropes.columns = ['trope_id', 'trope', 'description']
df_tropes.sample(5)
# Out:
#       trope_id                    trope  \
# 12131   t12132  JudgeJuryAndExecutioner
# 25846   t25847      WhatHappenedToMommy
# 20111   t20112                 Shipping
# 1781    t01782            BalancedHarem
# 13095   t13096        LockedRoomMystery
#
#                                              description
# 12131  In modern legal systems, the power to render j...
# 25846  One of the protagonists has a friend or loved ...
# 20111  Rooting for fictional romance to happen.\nThe ...
# 1781   A Subtrope of the Harem Anime genre, a Romanti...
# 13095  A seemingly impossible crime. The standard exa...

# %%
df_imdb_movie_tropes = pd.read_csv('../../data/tropes/film_imdb_match.csv', index_col=0)
df_imdb_movie_tropes.columns = ['title', 'trope', 'example', 'clean_title', 'tconst', 'trope_id', 'title_id']
df_imdb_movie_tropes = df_imdb_movie_tropes.drop(columns=['trope'])
df_imdb_movie_tropes.head()
# Out:
#           title                                            example  \
# 0  ABBATheMovie   The concert segments make it clear that Agnet...
# 1  ABBATheMovie   The radio station manager that tasks Ashley w...
# 2  ABBATheMovie   A rare male example; when Benny reads one new...
# 3  ABBATheMovie   During Ashley's fantasy sequence in which he ...
# 4  ABBATheMovie   Frida's outfit in the "Why Did It Have to Be ...
#
#     clean_title     tconst trope_id title_id
# 0  abbathemovie  tt0075617   t14656       f0
# 1  abbathemovie  tt0075617   t11527       f0
# 2  abbathemovie  tt0075617   t23019       f0
# 3  abbathemovie  tt0075617   t09016       f0
# 4  abbathemovie  tt0075617   t25994       f0

# %%
df_imdb_movie_tropes = df_imdb_movie_tropes.merge(df_tropes, how='inner', left_on='trope_id', right_on='trope_id')
df_imdb_movie_tropes = df_imdb_movie_tropes[['tconst', 'title_id', 'clean_title', 'trope_id', 'trope', 'description', 'example']]
df_imdb_movie_tropes.rename(columns={'tconst': 'imdb_id'}, inplace=True)
df_imdb_movie_tropes.head()
# Out:
#      imdb_id title_id   clean_title trope_id                    trope  \
# 0  tt0075617       f0  abbathemovie   t14656             MsFanservice
# 1  tt0075617       f0  abbathemovie   t11527     InsistentTerminology
# 2  tt0075617       f0  abbathemovie   t23019               TheIngenue
# 3  tt0075617       f0  abbathemovie   t09016  GettingCrapPastTheRadar
# 4  tt0075617       f0  abbathemovie   t25994      WhoWearsShortShorts
#
#                                          description  \
# 0  \nA female character who provides a significan...
# 1  \nHey, we aren't "describing" Insistent Termin...
# 2  \nThe Ingenuenote pronounced ON-jeh-noo is a y...
# 3  \n\nGetting Crap Past the Radar refers to inst...
# 4  \nHot pants, mini shorts, or daisy dukes? What...
#
#                                              example
# 0   The concert segments make it clear that Agnet...
# 1   The radio station manager that tasks Ashley w...
# 2   A rare male example; when Benny reads one new...
# 3   During Ashley's fantasy sequence in which he ...
# 4   Frida's outfit in the "Why Did It Have to Be ...

# %%
K = 10
top_k_tropes = df_imdb_movie_tropes['trope'].value_counts().reset_index().head(K)
top_k_tropes
# Out:
#                trope  count
# 0           ShoutOut   1151
# 1        HorrorFilms   1072
# 2    FilmsOfThe1980s    771
# 3             OhCrap    719
# 4        ChekhovsGun    716
# 5             BigBad    635
# 6      Foreshadowing    627
# 7     DeadpanSnarker    555
# 8           TheCameo    552
# 9  BittersweetEnding    513

# %% [markdown]
# #### IMDB dataset
#
# Link to download the data: https://developer.imdb.com/non-commercial-datasets/, download the title.basics.tsv.gz file

# %%
df_imdb = pd.read_csv('../../data/imdb/title.basics.tsv', sep='\t')
df_imdb.sample(5)
# Out:
# /var/folders/18/m5t215b91099mhnt7b5bl5sr0000gn/T/ipykernel_56584/215077895.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_imdb = pd.read_csv('../../data/imdb/title.basics.tsv', sep='\t')
#              tconst  titleType  \
# 341338    tt0356488      short
# 6547648   tt2752332  tvEpisode
# 3211382  tt14112194  tvEpisode
# 4947250   tt1908264  tvEpisode
# 6601086  tt27669641  tvEpisode
#
#                                               primaryTitle  \
# 341338                                     Cousin of Sleep
# 6547648                                    New Kid in Town
# 3211382                                      Episode #1.20
# 4947250                         Episode dated 19 July 2007
# 6601086  Better than Mario Party. JK It sucks. (with Ra...
#
#                                              originalTitle isAdult startYear  \
# 341338                                     Cousin of Sleep       0      2001
# 6547648                                    New Kid in Town       0      2013
# 3211382                                      Episode #1.20       0        \N
# 4947250                         Episode dated 19 July 2007       0      2007
# 6601086  Better than Mario Party. JK It sucks. (with Ra...       0      2023
#
#         endYear runtimeMinutes                genres
# 341338       \N             27           Drama,Short
# 6547648      \N             44  Adventure,Reality-TV
# 3211382      \N             \N                 Drama
# 4947250      \N             \N            Reality-TV
# 6601086      \N             \N                Comedy

# %% [markdown]
# #### TMDB dataset
#
# Link to download the data: https://www.kaggle.com/datasets/asaniczka/tmdb-movies-dataset-2023-930k-movies?resource=download

# %%
df_tmdb = pd.read_csv('../../data/tmdb/TMDB_movie_dataset_v11.csv')
df_tmdb.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords'],
#       dtype='object')

# %%
df_tmdb.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4     The Avengers  When an unexpected enemy emerges and threatens...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1    140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2    130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
# [5 rows x 24 columns]

# %%
df_tmdb['release_year'] = df_tmdb['release_date'].apply(extract_year)
df_tmdb.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#                                             overview popularity  \
# 0  Cobb, a skilled thief who commits corporate es...     83.952
# 1  The adventures of a group of explorers who mak...    140.241
# 2  Batman raises the stakes in his war on crime. ...    130.643
# 3  In the 22nd century, a paraplegic Marine is di...     79.932
# 4  When an unexpected enemy emerges and threatens...     98.082
#
#                         poster_path  \
# 0  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords release_year
# 0  rescue, mission, dream, airplane, paris, franc...         2010
# 1  rescue, future, spacecraft, race against time,...         2014
# 2  joker, sadism, chaos, secret identity, crime f...         2008
# 3  future, society, culture clash, space travel, ...         2009
# 4  new york city, superhero, shield, based on com...         2012
#
# [5 rows x 25 columns]

# %%
# Check tmdb dataset shape before filtering
df_tmdb.shape
# Out:
# (1131296, 25)

# %%
# Clean tmdb dataset before merging it with the cmu dataset

# Filter released movies
df_tmdb = df_tmdb[df_tmdb['status'] == 'Released']
print("Number of released movies in tmdb dataset: ", df_tmdb.shape)
# Out:
# Number of released movies in tmdb dataset:  (1105740, 25)

# %%
# Drop movies with missing release date
df_tmdb.dropna(subset=['release_date'], inplace=True)
print("Number of movies with release date information: ", df_tmdb.shape)
# Out:
# Number of movies with release date information:  (938049, 25)

# %% [markdown]
# ##### Merge IMDB and Tropes datasets

# %%
# tropes with imdb ids matched
df_imdb_movie_tropes.head()
# Out:
#      imdb_id title_id   clean_title trope_id                    trope  \
# 0  tt0075617       f0  abbathemovie   t14656             MsFanservice
# 1  tt0075617       f0  abbathemovie   t11527     InsistentTerminology
# 2  tt0075617       f0  abbathemovie   t23019               TheIngenue
# 3  tt0075617       f0  abbathemovie   t09016  GettingCrapPastTheRadar
# 4  tt0075617       f0  abbathemovie   t25994      WhoWearsShortShorts
#
#                                          description  \
# 0  \nA female character who provides a significan...
# 1  \nHey, we aren't "describing" Insistent Termin...
# 2  \nThe Ingenuenote pronounced ON-jeh-noo is a y...
# 3  \n\nGetting Crap Past the Radar refers to inst...
# 4  \nHot pants, mini shorts, or daisy dukes? What...
#
#                                              example
# 0   The concert segments make it clear that Agnet...
# 1   The radio station manager that tasks Ashley w...
# 2   A rare male example; when Benny reads one new...
# 3   During Ashley's fantasy sequence in which he ...
# 4   Frida's outfit in the "Why Did It Have to Be ...

# %%
# merge imdb titles basics information with tropes
df_movie_tropes = pd.merge(df_imdb_movie_tropes, df_imdb, how='inner', left_on='imdb_id', right_on='tconst')

# %%
print("-------" * 10)
print(f"imdb shape: {df_imdb.shape}")
print(f"movie tropes imdb shape: {df_imdb_movie_tropes.shape}")
print(f"movie tropes merged with imdb dataset shape: {df_movie_tropes.shape}")
print("-------" * 10)

df_movie_tropes.head()
# Out:
# ----------------------------------------------------------------------
# imdb shape: (11230548, 9)
# movie tropes imdb shape: (390511, 7)
# movie tropes merged with imdb dataset shape: (390408, 16)
# ----------------------------------------------------------------------
#      imdb_id title_id   clean_title trope_id                    trope  \
# 0  tt0075617       f0  abbathemovie   t14656             MsFanservice
# 1  tt0075617       f0  abbathemovie   t11527     InsistentTerminology
# 2  tt0075617       f0  abbathemovie   t23019               TheIngenue
# 3  tt0075617       f0  abbathemovie   t09016  GettingCrapPastTheRadar
# 4  tt0075617       f0  abbathemovie   t25994      WhoWearsShortShorts
#
#                                          description  \
# 0  \nA female character who provides a significan...
# 1  \nHey, we aren't "describing" Insistent Termin...
# 2  \nThe Ingenuenote pronounced ON-jeh-noo is a y...
# 3  \n\nGetting Crap Past the Radar refers to inst...
# 4  \nHot pants, mini shorts, or daisy dukes? What...
#
#                                              example     tconst titleType  \
# 0   The concert segments make it clear that Agnet...  tt0075617     movie
# 1   The radio station manager that tasks Ashley w...  tt0075617     movie
# 2   A rare male example; when Benny reads one new...  tt0075617     movie
# 3   During Ashley's fantasy sequence in which he ...  tt0075617     movie
# 4   Frida's outfit in the "Why Did It Have to Be ...  tt0075617     movie
#
#       primaryTitle    originalTitle isAdult startYear endYear runtimeMinutes  \
# 0  ABBA: The Movie  ABBA: The Movie       0      1977      \N             95
# 1  ABBA: The Movie  ABBA: The Movie       0      1977      \N             95
# 2  ABBA: The Movie  ABBA: The Movie       0      1977      \N             95
# 3  ABBA: The Movie  ABBA: The Movie       0      1977      \N             95
# 4  ABBA: The Movie  ABBA: The Movie       0      1977      \N             95
#
#                      genres
# 0  Comedy,Documentary,Music
# 1  Comedy,Documentary,Music
# 2  Comedy,Documentary,Music
# 3  Comedy,Documentary,Music
# 4  Comedy,Documentary,Music

# %%
df_movie_tropes.to_csv('../../data/movie_tropes.csv', index=False)

# %% [markdown]
# #### Merge CMU and TMDB datasets

# %%
df_cmu_movie_metadata.columns
# Out:
# Index(['wikipedia_movie_id', 'freebase_movie_id', 'name', 'release_date',
#        'revenue', 'runtime', 'languages', 'countries', 'genres',
#        'release_year'],
#       dtype='object')

# %%
df_tmdb.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords', 'release_year'],
#       dtype='object')

# %% [markdown]
# Example before merging:

# %%
MOVIE = 'Avatar'

# %%
df_cmu_movie_metadata[df_cmu_movie_metadata['name'] == MOVIE]
# Out:
#        wikipedia_movie_id freebase_movie_id    name release_date  \
# 23702             4273140         /m/0bth54  Avatar   2009-12-10
# 52274            15945267        /m/03qhwlm  Avatar         2004
#
#             revenue  runtime  \
# 23702  2.782275e+09    178.0
# 52274           NaN     90.0
#
#                                                languages  \
# 23702  {"/m/02h40lc": "English Language", "/m/06nm1":...
# 52274                 {"/m/02h40lc": "English Language"}
#
#                                                countries  \
# 23702  {"/m/09c7w0": "United States of America", "/m/...
# 52274                          {"/m/06t2t": "Singapore"}
#
#                                                   genres release_year
# 23702  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...         2009
# 52274  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...         2004

# %%
df_tmdb[df_tmdb['title'] == MOVIE]
# Out:
#              id   title  vote_average  vote_count    status release_date  \
# 3         19995  Avatar         7.573       29815  Released   2009-12-15
# 45668   1096978  Avatar         6.022          23  Released   2006-04-11
# 69784    282908  Avatar         5.875          12  Released   2011-04-30
# 105594   421403  Avatar         6.300           6  Released   1941-09-16
# 515600  1295181  Avatar         0.000           0  Released   1916-03-06
#
#            revenue  runtime  adult                     backdrop_path  ...  \
# 3       2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 45668            0       15  False  /pzgzH4LJoFmQKVPgKs0VZPWUoFZ.jpg  ...
# 69784            0       93  False  /gO81IsgrhwUS6aChXCjnjFKUS3S.jpg  ...
# 105594           0      114  False                               NaN  ...
# 515600           0       50  False  /mljnZyk8gwO2YH9EDC5SMy4XgeP.jpg  ...
#
#                                                  overview popularity  \
# 3       In the 22nd century, a paraplegic Marine is di...     79.932
# 45668   Tension mounts between a quadraplegic man and ...      4.098
# 69784   Michiko lost her dad in a car accident when sh...      3.005
# 105594  Indranath’s son is ill, Guru Omkarananda sugge...      0.771
# 515600  Based on Théophile Gautier's novel of the same...      1.400
#
#                              poster_path                      tagline  \
# 3       /kyeqWdyUXW608qlYkRqosgbbJyK.jpg  Enter the world of Pandora.
# 45668   /gmnD2e1RvMdCl9D1rsDEQaQlJxK.jpg      A bizarre love story...
# 69784   /xEAhV18F5Ej78qL0EneyPqa2a20.jpg                          NaN
# 105594                               NaN                          NaN
# 515600  /nUTlHxnwomoIwojD0AF0OMzkonw.jpg                          NaN
#
#                                              genres  \
# 3       Action, Adventure, Fantasy, Science Fiction
# 45668                                         Drama
# 69784                                        Horror
# 105594                                          NaN
# 515600                               Drama, Fantasy
#
#                                      production_companies  \
# 3       Dune Entertainment, Lightstorm Entertainment, ...
# 45668                                          Just Films
# 69784                                                 NaN
# 105594                                                NaN
# 515600                             Società Italiana Cines
#
#                             production_countries  spoken_languages  \
# 3       United States of America, United Kingdom  English, Spanish
# 45668                                      Spain           Spanish
# 69784                                      Japan          Japanese
# 105594                                       NaN               NaN
# 515600                                     Italy       No Language
#
#                                                  keywords release_year
# 3       future, society, culture clash, space travel, ...         2009
# 45668                                                 NaN         2006
# 69784                                                 NaN         2011
# 105594                                                NaN         1941
# 515600                                                NaN         1916
#
# [5 rows x 25 columns]

# %% [markdown]
# Merging the CMU and TMDB datasets by movie name and release year

# %%
# merge cmu movie metadata with tmdb dataset to fill in missing information such as revenue which has a lot of missing values
df_cmu_movie_metadata = df_cmu_movie_metadata[['wikipedia_movie_id', 'freebase_movie_id', 'name', 'release_year']]
df_cmu_tmdb = pd.merge(
    df_tmdb,
    df_cmu_movie_metadata,
    how='inner',
    left_on=['title','release_year'],
    right_on=['name', 'release_year']
)

print("-------" * 10)
print(f"CMU Movie Summary Corpus shape: {df_cmu_movie_metadata.shape}")
print(f"TMDB shape: {df_tmdb.shape}")
print(f"CMU TMDB merged dataframe shape: {df_cmu_tmdb.shape}")
print("-------" * 10)

df_cmu_tmdb.head()
# Out:
# ----------------------------------------------------------------------
# CMU Movie Summary Corpus shape: (74839, 4)
# TMDB shape: (938049, 25)
# CMU TMDB merged dataframe shape: (50630, 28)
# ----------------------------------------------------------------------
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords  release_year  \
# 0  rescue, mission, dream, airplane, paris, franc...          2010
# 1  rescue, future, spacecraft, race against time,...          2014
# 2  joker, sadism, chaos, secret identity, crime f...          2008
# 3  future, society, culture clash, space travel, ...          2009
# 4  new york city, superhero, shield, based on com...          2012
#
#   wikipedia_movie_id freebase_movie_id             name
# 0           23270459        /m/0661ql3        Inception
# 1            6009939         /m/0fkf28     Interstellar
# 2            4276475         /m/0btpm6  The Dark Knight
# 3            4273140         /m/0bth54           Avatar
# 4           22114132        /m/062zm5h     The Avengers
#
# [5 rows x 28 columns]

# %% [markdown]
# Check the results of the merge for the following movie:

# %%
df_cmu_tmdb[df_cmu_tmdb['title'] == MOVIE]
# Out:
#       id   title  vote_average  vote_count    status release_date     revenue  \
# 3  19995  Avatar         7.573       29815  Released   2009-12-15  2923706026
#
#    runtime  adult                     backdrop_path  ...  \
# 3      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
#
#                        tagline                                       genres  \
# 3  Enter the world of Pandora.  Action, Adventure, Fantasy, Science Fiction
#
#                                 production_companies  \
# 3  Dune Entertainment, Lightstorm Entertainment, ...
#
#                        production_countries  spoken_languages  \
# 3  United States of America, United Kingdom  English, Spanish
#
#                                             keywords  release_year  \
# 3  future, society, culture clash, space travel, ...          2009
#
#   wikipedia_movie_id freebase_movie_id    name
# 3            4273140         /m/0bth54  Avatar
#
# [1 rows x 28 columns]

# %% [markdown]
# Before saving the data, inspect that column names, and non-null values are correct

# %%
df_cmu_tmdb.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords', 'release_year', 'wikipedia_movie_id', 'freebase_movie_id',
#        'name'],
#       dtype='object')

# %%
df_cmu_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50630 entries, 0 to 50629
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    50630 non-null  int64
#  1   title                 50630 non-null  object
#  2   vote_average          50630 non-null  float64
#  3   vote_count            50630 non-null  int64
#  4   status                50630 non-null  object
#  5   release_date          50630 non-null  object
#  6   revenue               50630 non-null  int64
#  7   runtime               50630 non-null  int64
#  8   adult                 50630 non-null  bool
#  9   backdrop_path         34516 non-null  object
#  10  budget                50630 non-null  int64
#  11  homepage              4285 non-null   object
#  12  imdb_id               49516 non-null  object
#  13  original_language     50630 non-null  object
#  14  original_title        50630 non-null  object
#  15  overview              49527 non-null  object
#  16  popularity            50630 non-null  float64
#  17  poster_path           46520 non-null  object
#  18  tagline               22984 non-null  object
#  19  genres                47419 non-null  object
#  20  production_companies  40400 non-null  object
#  21  production_countries  45036 non-null  object
#  22  spoken_languages      45390 non-null  object
#  23  keywords              31540 non-null  object
#  24  release_year          50630 non-null  object
#  25  wikipedia_movie_id    50630 non-null  int64
#  26  freebase_movie_id     50630 non-null  object
#  27  name                  50630 non-null  object
# dtypes: bool(1), float64(2), int64(6), object(19)
# memory usage: 10.5+ MB

# %%
# Remove movies with missing imdb because we need it for the tropes analysis
df_cmu_tmdb.dropna(subset=['imdb_id'], inplace=True)
df_cmu_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49516 entries, 0 to 50629
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    49516 non-null  int64
#  1   title                 49516 non-null  object
#  2   vote_average          49516 non-null  float64
#  3   vote_count            49516 non-null  int64
#  4   status                49516 non-null  object
#  5   release_date          49516 non-null  object
#  6   revenue               49516 non-null  int64
#  7   runtime               49516 non-null  int64
#  8   adult                 49516 non-null  bool
#  9   backdrop_path         34367 non-null  object
#  10  budget                49516 non-null  int64
#  11  homepage              4220 non-null   object
#  12  imdb_id               49516 non-null  object
#  13  original_language     49516 non-null  object
#  14  original_title        49516 non-null  object
#  15  overview              48544 non-null  object
#  16  popularity            49516 non-null  float64
#  17  poster_path           45866 non-null  object
#  18  tagline               22914 non-null  object
#  19  genres                46722 non-null  object
#  20  production_companies  40031 non-null  object
#  21  production_countries  44464 non-null  object
#  22  spoken_languages      44709 non-null  object
#  23  keywords              31396 non-null  object
#  24  release_year          49516 non-null  object
#  25  wikipedia_movie_id    49516 non-null  int64
#  26  freebase_movie_id     49516 non-null  object
#  27  name                  49516 non-null  object
# dtypes: bool(1), float64(2), int64(6), object(19)
# memory usage: 10.6+ MB

# %%
df_cmu_tmdb.to_csv('../../data/cmu_tmdb.csv', index=False)
